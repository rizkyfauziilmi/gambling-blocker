# %%
import pandas as pd

df = pd.read_json('dataset/raw_dataset.jsonl', lines=True)

df.tail()
# Out:
#             timestamp             domain                         url  \
# 0 2026-04-13 21:08:05  www.tokopedia.com  https://www.tokopedia.com/
# 1 2026-04-13 21:08:05       kitabisa.com       https://kitabisa.com/
#
#   domain_ext  http_status                                          raw_title  \
# 0        com          200  Situs Jual Beli Online Terlengkap, Mudah & Ama...
# 1        com          200  Kitabisa - Donasi, Zakat, Wakaf, dan Saling Ja...
#
#                                        raw_meta_desc  label
# 0  Situs jual beli online terlengkap dengan berba...      0
# 1  Wadah galang dana, sedekah, zakat maal dan fit...      0
