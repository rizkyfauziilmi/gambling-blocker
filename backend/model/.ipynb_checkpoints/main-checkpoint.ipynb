# %%
import pandas as pd

df = pd.read_json('dataset/raw_dataset.jsonl', lines=True)

df.tail()
# Out:
#              timestamp                url_original  \
# 11 2026-04-12 13:01:41  https://www.antaranews.com
# 12 2026-04-12 13:01:42         https://www.grid.id
# 13 2026-04-12 13:01:42        https://www.inews.id
# 14 2026-04-12 13:01:43   https://www.sindonews.com
# 15 2026-04-12 13:05:51      https://www.google.com
#
#                       url_final domain_ext  http_status  \
# 11  https://www.antaranews.com/        com          200
# 12         https://www.grid.id/         id          200
# 13        https://www.inews.id/         id          200
# 14   https://www.sindonews.com/        com          200
# 15      https://www.google.com/        com          200
#
#                                             raw_title  \
# 11  Berita terkini dan terpercaya Indonesia - ANTA...
# 12  Celebrity Breaking News - Berita Artis Terkini...
# 13      Berita Terkini dan Informasi Terbaru Hari Ini
# 14  Berita Terkini dan Informasi Terbaru Hari Ini ...
# ...
